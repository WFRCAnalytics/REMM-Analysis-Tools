# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
inputs = r'.\graphing_inputs'
outputs = r'.\outputs'

# %% [markdown]
# ### sample table

# %%
example = pd.read_csv(os.path.join(inputs, 'run_285_2015_county_dev.csv'))
example.head()
# Out:
#    county_id  residential_units  job_spaces  job_spaces_added  \
# 0          3                0.0         0.0               0.0
# 1         11           114552.0    173224.0             549.0
# 2         35           406213.0    849965.0            3452.0
# 3         49           176299.0    309339.0            6313.0
# 4         57            95013.0    130836.0             822.0
#
#    res_units_added  building_count  acreage_dev  acreage_redev   total_value  \
# 0              0.0             0.0     0.000000       0.000000  6.919964e+05
# 1           5579.0         97341.0   504.669025     153.002492  3.542362e+10
# 2           3747.0        331981.0   163.246469      86.319699  2.263596e+13
# 3           5890.0        151798.0  1365.864797      58.173881  5.506315e+13
# 4              0.0         87578.0    12.455135       0.000000  2.168911e+10
#
#    value_added_dev  value_added_redev  res_units_added_dev  \
# 0     0.000000e+00       0.000000e+00                  0.0
# 1     5.521836e+08       3.383183e+08               4013.0
# 2     8.101690e+08       6.845849e+08               1908.0
# 3     1.615582e+09       1.289522e+08               5463.0
# 4     1.097923e+08       0.000000e+00                  0.0
#
#    res_units_added_redev  acreage_dev_res  acreage_dev_nonres  \
# 0                    0.0         0.000000            0.000000
# 1                 1566.0       503.456171            1.212854
# 2                 1839.0       137.007408           26.239061
# 3                  427.0      1146.477024          219.387773
# 4                    0.0         0.000000           12.455135
#
#    acreage_redev_res  acreage_redev_nonres
# 0           0.000000              0.000000
# 1         142.540438             10.462053
# 2          79.090617              7.229082
# 3          45.561309             12.612572
# 4           0.000000              0.000000

# %% [markdown]
# ### functions

# %%
# create dataframe with values of specified attribute by year
def create_county_dataframe(field, export=False):
    
    # create empty list
    rows = []
    
    # get list of files
    csvs = glob.glob(r'.\graphing_inputs\*_county_dev.csv')
    for csv in csvs:

        # get the year
        year= csv[26:30]

        # read in table
        df = pd.read_csv(csv)
        
        # get value for each county
        davis = float(df[df['county_id']== 11][field])
        saltlake = float(df[df['county_id']== 35][field])
        utah = float(df[df['county_id']== 49][field])
        weber = float(df[df['county_id']== 57][field])
        
        # form the row and append to the list
        row = (year, davis, saltlake, utah, weber)
        rows.append(row)

    # create dataframe from list of tuples, convert year col to int, filter to 2050 and earlier
    df2 = pd.DataFrame(rows, columns=["year", "davis", "salt_lake", "utah", "weber"])
    df2['year'] = df2['year'].astype(int)
    df2 = df2[df2['year'] <= 2050]

    # export to csv
    if export == True: 
        df2.to_csv(os.path.join(outputs, "remm_yearly_{}.csv".format(field)))
    
    return df2

# %% [markdown]
# ### job spaces added

# %%
df = create_county_dataframe('job_spaces_added')
df.set_index('year').plot(title='REMM: Job Spaces Added By Year')

# %% [markdown]
# ### acreage developed

# %%
df = create_county_dataframe('acreage_dev')
df.set_index('year').plot(title='REMM: Acreage Developed By Year')

# %% [markdown]
# ### acreage redeveloped

# %%
df = create_county_dataframe('acreage_redev')
df.set_index('year').plot(title='REMM: Acreage Redeveloped By Year')

# %% [markdown]
# ### residential units added by year

# %%
df = create_county_dataframe('res_units_added')
df.set_index('year').plot(title='REMM: Residential Units Added By Year')

# %% [markdown]
# ### residential units added by year (development)

# %%
df = create_county_dataframe('res_units_added_dev')
df.set_index('year').plot(title='REMM: Residential Units Added By Year (Development)')

# %% [markdown]
# ### residential units added by year (redevelopment)

# %%
df = create_county_dataframe('res_units_added_redev')
df.set_index('year').plot(title='REMM: Residential Units Added By Year (Redevelopment)')

# %% [markdown]
# ### value added (development)

# %%
df = create_county_dataframe('value_added_dev')
df.set_index('year').plot(title='REMM: Value Added By Year (Development)')

# %% [markdown]
# ### value added (redevelopment)

# %%
df = create_county_dataframe('value_added_redev')
df.set_index('year').plot(title='REMM: Value Added By Year (Redevelopment)')
